# %%
from pymongo import MongoClient
import pandas as pd
import time
import re
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
from dotenv import load_dotenv
import os
import requests
import warnings
warnings.filterwarnings("ignore")
from pymongo import GEOSPHERE
import json
#from cartoframes.viz import Map, Layer, popup_element
import geopandas as gpd
import geopy.distance

# %%
nyork_df = pd.read_csv("./dataset/new_york_data.csv")

# %%
load_dotenv()
# Out:
# True

# %%
token_fsq = os.getenv("token")

# %%
map2 = Map(location = ["40.751892", "-73.987592"], zoom_start = 15)

# %%
#add crispy game location

# %%
icon = Icon(color = "blue",
            opacity = 0.1,
            prefix = "fa",
            icon = "building",
            icon_color = "black"
)
Crispy_Gamer = Marker(
    location = [40.750597, -73.985273],
    tooltip = "Crispy Gamer",
    icon=icon
)
Crispy_Gamer.add_to(map2)

# %%
#add "heavy" location

# %%
icon = Icon(color = "blue",
            opacity = 0.1,
            prefix = "fa",
            icon = "building",
            icon_color = "black"
)
Heavy = Marker(
    location = [40.753385, -73.989620],
    tooltip = "Heavy",
    icon=icon
)
Heavy.add_to(map2)

# %%
#add Optimum_Energy location

# %%
icon = Icon(color = "blue",
            opacity = 0.1,
            prefix = "fa",
            icon = "building",
            icon_color = "black",
)
Optimum_Energy = Marker(
    location = [40.751892, -73.987592],
    tooltip = "Optimum Energy",
    icon=icon
)
Optimum_Energy.add_to(map2)

# %%
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96e457239e03183e7832673b46802335 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96e457239e03183e7832673b46802335&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_96e457239e03183e7832673b46802335 = L.map(
#                 &quot;map_96e457239e03183e7832673b46802335&quot;,
#                 {
#                     center: [40.751892, -73.987592],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dae680204ea5e23dd2a581df30c5a27f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var marker_3ce9ee20c3e71256ba706574ce177231 = L.marker(
#                 [40.750597, -73.985273],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_12bc5d542328492d7d996b751e073a83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;database&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3ce9ee20c3e71256ba706574ce177231.setIcon(icon_12bc5d542328492d7d996b751e073a83);
#
#
#             marker_3ce9ee20c3e71256ba706574ce177231.bindTooltip(
#                 `&lt;div&gt;
#                      Crispy Gamer
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d2916816d8704406f1bfc5218b1999e = L.marker(
#                 [40.750597, -73.985273],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_1155975506963ac57e6276d8cc6e738a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2d2916816d8704406f1bfc5218b1999e.setIcon(icon_1155975506963ac57e6276d8cc6e738a);
#
#
#             marker_2d2916816d8704406f1bfc5218b1999e.bindTooltip(
#                 `&lt;div&gt;
#                      Crispy Gamer
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f4857c1163095031b7d1857707d5378b = L.marker(
#                 [40.753385, -73.98962],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_21263f69525f6a05bc4c18573ded2a8d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f4857c1163095031b7d1857707d5378b.setIcon(icon_21263f69525f6a05bc4c18573ded2a8d);
#
#
#             marker_f4857c1163095031b7d1857707d5378b.bindTooltip(
#                 `&lt;div&gt;
#                      Heavy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eaabdd54c142739399a559e7b8832dc7 = L.marker(
#                 [40.751892, -73.987592],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_8c7a6e97a4cb3408202c2dbcb015f497 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_eaabdd54c142739399a559e7b8832dc7.setIcon(icon_8c7a6e97a4cb3408202c2dbcb015f497);
#
#
#             marker_eaabdd54c142739399a559e7b8832dc7.bindTooltip(
#                 `&lt;div&gt;
#                      Optimum Energy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cae8483f15e62728ed1f78e0b659808f = L.marker(
#                 [40.751892, -73.987592],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_6508c77e6ebc5f07b955d0f37b5aefef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;, &quot;radius&quot;: 1000}
#             );
#             marker_cae8483f15e62728ed1f78e0b659808f.setIcon(icon_65

# %%
def getNearbyStarbucks(lat, long, radius=500):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&chains=ab4c54c0-d68a-012e-5619-003048cad9da&exclude_all_chains=false&sort=DISTANCE&limit=10"        
    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }
    
    response = requests.get(url,headers=headers).json()    
    return response

# %%
response_star = getNearbyStarbucks("40.751892","-73.987592")

# %%
starbucks = []
for i in response_star["results"]:
    
    name = i["name"]
    latitude = i["geocodes"]["main"]["latitude"]
    longitude = i["geocodes"]["main"]["longitude"]
    distance = i["distance"]
    
    starbucks.append({"name":name, "latitude":latitude, "longitude":longitude, "distance_Optimum Energy": distance})
    
    starbucks

# %%
df_cafe = pd.DataFrame(starbucks)

# %%
for index, row in df_cafe.iterrows():
    
    #1. MARKER without icon
    starbucks = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    
    #2. Icon
          
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon="coffee",
            icon_color = "black"
        )
     #3. Marker
    new_marker = Marker(**starbucks, icon = icon, radius = 100)
    
    #4. Add the Marker
    new_marker.add_to(map2)

# %%
new_marker.add_to(map2)

# %%
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96e457239e03183e7832673b46802335 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96e457239e03183e7832673b46802335&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_96e457239e03183e7832673b46802335 = L.map(
#                 &quot;map_96e457239e03183e7832673b46802335&quot;,
#                 {
#                     center: [40.751892, -73.987592],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dae680204ea5e23dd2a581df30c5a27f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var marker_3ce9ee20c3e71256ba706574ce177231 = L.marker(
#                 [40.750597, -73.985273],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_12bc5d542328492d7d996b751e073a83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;database&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3ce9ee20c3e71256ba706574ce177231.setIcon(icon_12bc5d542328492d7d996b751e073a83);
#
#
#             marker_3ce9ee20c3e71256ba706574ce177231.bindTooltip(
#                 `&lt;div&gt;
#                      Crispy Gamer
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d2916816d8704406f1bfc5218b1999e = L.marker(
#                 [40.750597, -73.985273],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_1155975506963ac57e6276d8cc6e738a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2d2916816d8704406f1bfc5218b1999e.setIcon(icon_1155975506963ac57e6276d8cc6e738a);
#
#
#             marker_2d2916816d8704406f1bfc5218b1999e.bindTooltip(
#                 `&lt;div&gt;
#                      Crispy Gamer
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f4857c1163095031b7d1857707d5378b = L.marker(
#                 [40.753385, -73.98962],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_21263f69525f6a05bc4c18573ded2a8d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f4857c1163095031b7d1857707d5378b.setIcon(icon_21263f69525f6a05bc4c18573ded2a8d);
#
#
#             marker_f4857c1163095031b7d1857707d5378b.bindTooltip(
#                 `&lt;div&gt;
#                      Heavy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eaabdd54c142739399a559e7b8832dc7 = L.marker(
#                 [40.751892, -73.987592],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_8c7a6e97a4cb3408202c2dbcb015f497 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_eaabdd54c142739399a559e7b8832dc7.setIcon(icon_8c7a6e97a4cb3408202c2dbcb015f497);
#
#
#             marker_eaabdd54c142739399a559e7b8832dc7.bindTooltip(
#                 `&lt;div&gt;
#                      Optimum Energy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cae8483f15e62728ed1f78e0b659808f = L.marker(
#                 [40.751892, -73.987592],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_6508c77e6ebc5f07b955d0f37b5aefef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;, &quot;radius&quot;: 1000}
#             );
#             marker_cae8483f15e62728ed1f78e0b659808f.setIcon(icon_65

# %%
def getNearbyLocation(lat, long, categorie, radius=1000):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&categories={categorie}&exclude_all_chains=false&sort=DISTANCE&limit=10"

    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }    
    response = requests.get(url,headers=headers).json()    
    
    return response

# %%
night_life_response = getNearbyLocation("40.751892","-73.987592","13003")

# %%
night_life = []
for i in night_life_response["results"]:
    
    name = i["name"]
    latitude = i["geocodes"]["main"]["latitude"]
    longitude = i["geocodes"]["main"]["longitude"]
    distance = i["distance"]
    
    night_life.append({"name":name, "latitude":latitude, "longitude":longitude, "distance_Optimum Energy": distance})
    
    night_life

# %%
df_night_life = pd.DataFrame(night_life)
df_night_life
# Out:
#                               name   latitude  longitude  \
# 0                         Bar Moxy  40.752206 -73.989137
# 1  Magic Hour Rooftop Bar & Lounge  40.752366 -73.989187
# 2                        The Heist  40.751598 -73.985662
# 3                  Monarch Rooftop  40.750485 -73.986929
# 4                     The Keg Room  40.750887 -73.986028
# 5                 Refinery Rooftop  40.752257 -73.985251
# 6                            Stout  40.753321 -73.986039
# 7                  John Sullivan's  40.751629 -73.990512
# 8                      Barn Joo 35  40.749756 -73.985940
# 9                      The Skylark  40.754105 -73.988731
#
#    distance_Optimum Energy
# 0                      144
# 1                      147
# 2                      165
# 3                      179
# 4                      183
# 5                      192
# 6                      199
# 7                      251
# 8                      266
# 9                      274

# %%
for index, row in df_night_life.iterrows():
    
    #1. MARKER without icon
    nightlife = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    
    #2. Icon
          
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon="beer",
            icon_color = "black"
        )
     #3. Marker
    new_marker1 = Marker(**nightlife, icon = icon, radius = 500)
    
    #4. Add the Marker
    new_marker1.add_to(map2)

# %%
def getNearbyLocation(lat, long, categorie, radius=1000):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&categories={categorie}&exclude_all_chains=false&sort=DISTANCE&limit=10"

    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }    
    response = requests.get(url,headers=headers).json()    
    
    return response

# %%
#transportation
transportation_response = getNearbyLocation("40.751892","-73.987592","19047,19049,19046")#19047 rail
#19049 taxi
#19046 metro

# %% [markdown]
# coords_1 = (40.751892,-73.987592)
# coords_2 = (40.752206,-73.989137)
# print (geopy.distance.geodesic(coords_1, coords_2).km)

# %%
transportation = []
for i in transportation_response["results"]:
    
    name = i["name"]
    latitude = i["geocodes"]["main"]["latitude"]
    longitude = i["geocodes"]["main"]["longitude"]
    distance = i["distance"]
    
    transportation.append({"name":name, "latitude":latitude, "longitude":longitude, "distance_Optimum Energy": distance})
    
    transportation

# %%
df_transportation = pd.DataFrame(transportation)
df_transportation
# Out:
#                                                name   latitude  longitude  \
# 0  MTA - 34th Street - Herald Square Subway Station  40.749805 -73.988125
# 1                                Go Airlink Shuttle  40.754056 -73.986545
# 2                                       N Y Checker  40.750484 -73.984964
# 3                                              Gett  40.752310 -73.991281
# 4                                  New York Kokusai  40.753953 -73.990385
# 5  LIRR Train - New York Penn Station to Ronkonkoma  40.750688 -73.991392
# 6                                   Uber Taxi Clone  40.749174 -73.985524
# 7                        LIRR Tickets & Information  40.750690 -73.991305
# 8                               33rd Street Station  40.748873 -73.988657
# 9                               LIRR - Lost & Found  40.750048 -73.991105
#
#    distance_Optimum Energy
# 0                      219
# 1                      256
# 2                      270
# 3                      314
# 4                      328
# 5                      346
# 6                      348
# 7                      351
# 8                      370
# 9                      384

# %%
for index, row in df_transportation.iterrows():
    
    #1. MARKER without icon
    transportation = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    
    #2. Icon
          
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon="car",
            icon_color = "black"
        )
     #3. Marker
    new_marker2 = Marker(**transportation, icon = icon, radius = 1000)
    
    #4. Add the Marker
    new_marker2.add_to(map2)

# %%
preschool_response = getNearbyLocation("40.751892","-73.987592","12056")

# %%
preschool = []
for i in preschool_response["results"]:
    
    name = i["name"]
    latitude = i["geocodes"]["main"]["latitude"]
    longitude = i["geocodes"]["main"]["longitude"]
    distance = i["distance"]
    
    preschool.append({"name":name, "latitude":latitude, "longitude":longitude, "distance_Optimum Energy": distance})
    
    preschool

# %%
df_preschool = pd.DataFrame(preschool)
df_preschool
# Out:
#                                  name   latitude  longitude  \
# 0       Young Child Expo & Conference  40.754061 -73.992355
# 1                  Chelsea Day School  40.747135 -73.985094
# 2           Maryel School of New York  40.747929 -73.981675
# 3        Foundation for Child Develop  40.751816 -73.979599
# 4          KinderCare Learning Center  40.750587 -73.979158
# 5  Metrokids Preschool - Times Square  40.758187 -73.991570
# 6                         ReadingEggs  40.744967 -73.989464
# 7   Ivy League Early Learning Academy  40.744927 -73.990948
# 8          Webtoast Internet Services  40.756713 -73.980097
# 9           Murray Hill Wee Ones Club  40.747777 -73.979311
#
#    distance_Optimum Energy
# 0                      467
# 1                      573
# 2                      664
# 3                      672
# 4                      724
# 5                      775
# 6                      785
# 7                      811
# 8                      827
# 9                      848

# %%
for index, row in df_preschool.iterrows():
    
    #1. MARKER without icon
    preschool = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    
    #2. Icon
          
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon="child",
            icon_color = "black"
        )
     #3. Marker
    new_marker3 = Marker(**preschool, icon = icon, radius = 500)
    
    #4. Add the Marker
    new_marker3.add_to(map2)

# %%
vegan_response = getNearbyLocation("40.751892","-73.987592","13377")
vegan_response
# Out:
# {'results': [{'fsq_id': '5a072c7f419a9e21055e7cb6',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'e9b6ff79-62b5-4a0b-9ef6-b9bf15f3b53f',
#      'name': 'sweetgreen'}],
#    'distance': 77,
#    'geocodes': {'main': {'latitude': 40.752533, 'longitude': -73.987009},
#     'roof': {'latitude': 40.752533, 'longitude': -73.987009}},
#    'link': '/v3/places/5a072c7f419a9e21055e7cb6',
#    'location': {'address': '1384 Broadway',
#     'census_block': '360610109001000',
#     'country': 'US',
#     'cross_street': 'Between 37th St and 38th St',
#     'dma': 'New York',
#     'formatted_address': '1384 Broadway (Between 37th St and 38th St), New York, NY 10018',
#     'locality': 'New York',
#     'neighborhood': ['Garment District'],
#     'postcode': '10018',
#     'region': 'NY'},
#    'name': 'Sweetgreen',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '5910d26ffe37407bad2f8a4b',
#    'categories': [{'id': 13072,
#      'name': 'Asian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}},
#     {'id': 13276,
#      'name': 'Sushi Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 106,
#    'geocodes': {'main': {'latitude': 40.752383, 'longitude': -73.988576},
#     'roof': {'latitude': 40.752383, 'longitude': -73.988576}},
#    'link': '/v3/places/5910d26ffe37407bad2f8a4b',
#    'location': {'address': '134 W 37th St',
#     'census_block': '360610109001008',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'New York',
#     'formatted_address': '134 W 37th St, New York, NY 10018',
#     'locality': 'New York',
#     'neighborhood': ['Garment District'],
#     'postcode': '10018',
#     'region': 'NY'},
#    'name': 'Beyond Sushi Herald Square',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '6180455612b0ba7b3649466d',
#    'categories': [{'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 125,
#    'geocodes': {'main': {'latitude': 40.752997, 'longitude': -73.987877}},
#    'link': '/v3/places/6180455612b0ba7b3649466d',
#    'location': {'address': '1385 Broadway',
#     'census_block': '360610109001001',
#     'country': 'US',
#     'cross_street': 'W. 38th',
#     'dma': 'New York',
#     'formatted_address': '1385 Broadway (W. 38th), New York, NY 10018',
#     'locality': 'New York',
#     'neighborhood': ['Garment District'],
#     'postcode': '10018',
#     'region': 'NY'},
#    'name': 'Beatnic - Fashion District',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '54b5a33f85254c6062f8d42a',
#    'categories': [{'id': 13099,
#      'name': 'Chinese Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}},
#     {'id': 14013,
#      'name': 'Street Food Gathering',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 154,
#    'geocodes': {'main': {'latitude': 40.750593, 'longitude': -73.986933},
#     'roof': {'latitude': 40.750593, 'longitude': -73.986933}},
#    'link': '/v3/places/54b5a33f85254c6062f8d42a',
#    'location': {'address': '968 Avenue of the Americas',
#     'census_block': '360610084002004',
#     'country': 'US',
#     'dma': 'New York',
#     'formatted_address': '968 Avenue of the Americas, New York, NY 10018',
#     'locality': 'New York',
#     'neighborhood': ['Garment District'],
#     'postcode': '10018',
#     'region': 'NY'},
#    'name': 'Hong Kong Street Cart At Broadway Bites',
#    'related_places': {}},
#   {'fsq_id': '5644dc0f498ea0ff843ab26a',
#    'categories': [{'id': 13145,
#      'name': 'Fast Food Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'}},
#     {'id': 13334,
#      'name': 'Sandwich Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 392,
#    'geocodes': {'main': {'latitude': 40.748228, 'longitude': -73.986579},
#     'roof': {'latitude': 40.748228, 'longitude': -73.986579}},
#    'link': '/v3/places/5644dc0f498ea0ff843ab26a',
#    'location': {'address': '26 W 33rd St',
#     'census_block': '360610076001003',
#     'country': 'US',
#     'cross_street': 'Between 5th and 6th Ave.',
#     'dma': 'New York',
#     'formatted_address': '26 W 33rd St (Between 5th and 6th Ave.), Manhattan, NY 10001',
#     'locality': 'Manhattan',
#     'neighborhood': ['Flatiron'],
#     'postcode': '10001',
#     'region': 'NY'},
#    'name': 'Market Crates',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '4ee121f68231e61c74fb337a',
#    'categories': [{'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 409,
#    'geocodes': {'main': {'latitude': 40.753078, 'longitude': -73.982837},
#     'roof': {'latitude': 40.753078, 'longitude': -73.982837}},
#    'link': '/v3/places/4ee121f68231e61c74fb337a',
#    'location': {'address': 'Bryant Park F02',
#     'census_block': '360610084001000',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'New York',
#     'formatted_address': 'Bryant Park F02, New York, NY 10036',
#     'locality': 'New York',
#     'neighborhood': ['Garment District'],
#     'postcode': '10036',
#     'region': 'NY'},
#    'name': 'Vegetarian Oasis',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '574f2387cd10da9c734bbb21',
#    'categories': [{'id': 13068,
#      'name': 'American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13332,
#      'name': 'Salad Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 455,
#    'geocodes': {'main': {'latitude': 40.753637, 'longitude': -73.992076},
#     'roof': {'latitude': 40.753637, 'longitude': -73.992076}},
#    'link': '/v3/places/574f2387cd10da9c734bbb21',
#    'location': {'address': '520 8th Ave',
#     'census_block': '360610109001003',
#     'country': 'US',
#     'cross_street': 'W 36th St',
#     'dma': 'New York',
#     'formatted_address': '520 8th Ave (W 36th St), New York, NY 10018',
#     'locality': 'New York',
#     'neighborhood': ['Garment District'],
#     'postcode': '10018',
#     'region': 'NY'},
#    'name': 'Roast Kitchen',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '59c0b9fa0d173f674fadfaac',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'e9b6ff79-62b5-4a0b-9ef6-b9bf15f3b53f',
#      'name': 'sweetgreen'}],
#    'distance': 485,
#    'geocodes': {'main': {'latitude': 40.754747, 'longitude': -73.982946},
#     'roof': {'latitude': 40.754747, 'longitude': -73.982946}},
#    'link': '/v3/places/59c0b9fa0d173f674fadfaac',
#    'location': {'address': '1114 Avenue of the Americas',
#     'census_block': '360610096001003',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'New York',
#     'formatted_address': '1114 Avenue of the Americas, New York, NY 10036',
#     'locality': 'New York',
#     'neighborhood': ['Midtown'],
#     'postcode': '10036',
#     'region': 'NY'},
#    'name': 'Sweetgreen',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '5de5435bf851400008675561',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'e9b6ff79-62b5-4a0b-9ef6-b9bf15f3b53f',
#      'name': 'sweetgreen'}],
#    'distance': 541,
#    'geocodes': {'main': {'latitude': 40.74888, 'longitude': -73.992413},
#     'roof': {'latitude': 40.74888, 'longitude': -73.992413}},
#    'link': '/v3/places/5de5435bf851400008675561',
#    'location': {'address': '7 Pennsylvania Plaza',
#     'census_block': '360610101001004',
#     'country': 'US',
#     'cross_street': 'W. 30th St',
#     'dma': 'New York',
#     'formatted_address': '7 Pennsylvania Plaza (W. 30th St), New York, NY 10001',
#     'locality': 'New York',
#     'neighborhood': ['Chelsea'],
#     'postcode': '10001',
#     'region': 'NY'},
#    'name': 'Sweetgreen',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '71eb2550bef8012e48cad9da',
#    'categories': [{'id': 13342,
#      'name': 'Soup Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 588,
#    'geocodes': {'main': {'latitude': 40.753239, 'longitude': -73.980834},
#     'roof': {'latitude': 40.753239, 'longitude': -73.980834}},
#    'link': '/v3/places/71eb2550bef8012e48cad9da',
#    'location': {'address': '4 E 42nd St',
#     'census_block': '360610082002001',
#     'country': 'US',
#     'dma': 'New York',
#     'formatted_address': '4 E 42nd St, New York, NY 10017',
#     'locality': 'New York',
#     'neighborhood': ['Midtown'],
#     'postcode': '10017',
#     'region': 'NY'},
#    'name': 'The Original SoupMan',
#    'related_places': {}}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 40.751892,
#      'longitude': -73.987592},
#     'radius': 1000}}}}

# %%
vegan_rest = []
for i in vegan_response["results"]:
    
    name = i["name"]
    latitude = i["geocodes"]["main"]["latitude"]
    longitude = i["geocodes"]["main"]["longitude"]
    distance = i["distance"]
    
    vegan_rest.append({"name":name, "latitude":latitude, "longitude":longitude, "distance_Optimum Energy": distance})
    
    vegan_rest

# %%
df_vegan_rest = pd.DataFrame(vegan_rest)

# %%
for index, row in df_preschool.iterrows():
    
    #1. MARKER without icon
    vegan_rest = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    
    #2. Icon
          
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon="child",
            icon_color = "black"
        )
     #3. Marker
    new_marker4 = Marker(**vegan_rest, icon = icon, radius = 500)
    
    #4. Add the Marker
    new_marker4.add_to(map2)

# %%
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96e457239e03183e7832673b46802335 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96e457239e03183e7832673b46802335&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_96e457239e03183e7832673b46802335 = L.map(
#                 &quot;map_96e457239e03183e7832673b46802335&quot;,
#                 {
#                     center: [40.751892, -73.987592],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dae680204ea5e23dd2a581df30c5a27f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var marker_3ce9ee20c3e71256ba706574ce177231 = L.marker(
#                 [40.750597, -73.985273],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_12bc5d542328492d7d996b751e073a83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;database&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3ce9ee20c3e71256ba706574ce177231.setIcon(icon_12bc5d542328492d7d996b751e073a83);
#
#
#             marker_3ce9ee20c3e71256ba706574ce177231.bindTooltip(
#                 `&lt;div&gt;
#                      Crispy Gamer
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d2916816d8704406f1bfc5218b1999e = L.marker(
#                 [40.750597, -73.985273],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_1155975506963ac57e6276d8cc6e738a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2d2916816d8704406f1bfc5218b1999e.setIcon(icon_1155975506963ac57e6276d8cc6e738a);
#
#
#             marker_2d2916816d8704406f1bfc5218b1999e.bindTooltip(
#                 `&lt;div&gt;
#                      Crispy Gamer
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f4857c1163095031b7d1857707d5378b = L.marker(
#                 [40.753385, -73.98962],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_21263f69525f6a05bc4c18573ded2a8d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f4857c1163095031b7d1857707d5378b.setIcon(icon_21263f69525f6a05bc4c18573ded2a8d);
#
#
#             marker_f4857c1163095031b7d1857707d5378b.bindTooltip(
#                 `&lt;div&gt;
#                      Heavy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eaabdd54c142739399a559e7b8832dc7 = L.marker(
#                 [40.751892, -73.987592],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_8c7a6e97a4cb3408202c2dbcb015f497 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_eaabdd54c142739399a559e7b8832dc7.setIcon(icon_8c7a6e97a4cb3408202c2dbcb015f497);
#
#
#             marker_eaabdd54c142739399a559e7b8832dc7.bindTooltip(
#                 `&lt;div&gt;
#                      Optimum Energy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cae8483f15e62728ed1f78e0b659808f = L.marker(
#                 [40.751892, -73.987592],
#                 {}
#             ).addTo(map_96e457239e03183e7832673b46802335);
#
#
#             var icon_6508c77e6ebc5f07b955d0f37b5aefef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;, &quot;radius&quot;: 1000}
#             );
#             marker_cae8483f15e62728ed1f78e0b659808f.setIcon(icon_65
