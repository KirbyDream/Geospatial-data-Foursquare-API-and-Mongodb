# %%
from pymongo import MongoClient
import pandas as pd
import time
import re
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
from dotenv import load_dotenv
import os
import requests
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("./dataset/dataset.csv")

# %%
df
# Out:
#                   name            city   latitude   longitude country_code
# 0             Wetpaint         Seattle  47.603122 -122.333253          USA
# 1             Wetpaint        New York  40.723731  -73.996431          USA
# 2                 Digg   San Francisco  37.764726 -122.394523          USA
# 3                 Geni  West Hollywood  34.090368 -118.393064          USA
# 4          StumbleUpon   San Francisco  37.775196 -122.419204          USA
# ..                 ...             ...        ...         ...          ...
# 343         PhotoThera        Carlsbad  33.133240 -117.275027          USA
# 344             OpTier        New York  40.754937  -73.985647          USA
# 345    High Gear Media      Menlo Park  37.445335 -122.158330          USA
# 346  Clavis Technology       Cambridge  42.362663  -71.084153          USA
# 347    Arkeia Software        Carlsbad  33.132567 -117.292746          USA
#
# [348 rows x 5 columns]

# %%
load_dotenv()
# Out:
# True

# %%
token_fsq = os.getenv("token")

# %%
df.country_code.unique()
# Out:
# array(['USA', 'FRA', 'NLD', 'SGP', 'GBR', 'DEU', 'CHN', 'ESP', 'CAN',
#        'FIN', 'IRL'], dtype=object)

# %%
#this is a test
usa_df = df[df["country_code"] == "USA"]
usa_df
# Out:
#                   name            city   latitude   longitude country_code
# 0             Wetpaint         Seattle  47.603122 -122.333253          USA
# 1             Wetpaint        New York  40.723731  -73.996431          USA
# 2                 Digg   San Francisco  37.764726 -122.394523          USA
# 3                 Geni  West Hollywood  34.090368 -118.393064          USA
# 4          StumbleUpon   San Francisco  37.775196 -122.419204          USA
# ..                 ...             ...        ...         ...          ...
# 343         PhotoThera        Carlsbad  33.133240 -117.275027          USA
# 344             OpTier        New York  40.754937  -73.985647          USA
# 345    High Gear Media      Menlo Park  37.445335 -122.158330          USA
# 346  Clavis Technology       Cambridge  42.362663  -71.084153          USA
# 347    Arkeia Software        Carlsbad  33.132567 -117.292746          USA
#
# [305 rows x 5 columns]

# %%
#test api with country_code FRA, bc it doesn't have too many values

fra_df = df[df["country_code"] == "FRA"]
fra_df
# Out:
#                       name   city   latitude  longitude country_code
# 13                Netvibes  Paris  48.870806   2.346680          FRA
# 15                  TVtrip  Paris  48.856667   2.350987          FRA
# 80             FastBooking  Paris  37.090240 -95.712891          FRA
# 109              fotopedia  Paris  48.856667   2.350987          FRA
# 172              Zoomorama  Paris  48.854845   2.403520          FRA
# 327  Uniteam Communication  Paris  48.842278   2.310483          FRA

# %%
#the filter was split into 2 steps, 
#first filter we used a mongo query to select form the database design companies that had raised more than 10M$ and 
#for the second filter we are going to be using foursquare queries to :
#1- look for Starbucks cafes nearby, because everyone needs coffee
     #setting the radius to 500 and limiting search to 50.

# %%
#first trial was with 1000 radius, trying to narrow down more, 
#reducing radius to 500

def getNearbyStarbucks(lat, long, radius=500):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&chains=ab4c54c0-d68a-012e-5619-003048cad9da&exclude_all_chains=false&sort=DISTANCE&limit=50"        
    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }
    
    results = requests.get(url,headers=headers).json()["results"]
    
    return len(results)

# %%
for index, row in df.iterrows():
    df.at[index, "Starbucks"] = getNearbyStarbucks(row["latitude"],row["longitude"])

# %%
star_count = df["Starbucks"].value_counts()
#print(star_count.to_string())

# %%
df['Starbucks'].dtypes
df['Starbucks'] = df['Starbucks'].astype(int)

# %%
#pd.set_option('display.max_rows', 500)
#df

# %%
#deleting the locations with zero Starbucks nearby
df = df[df.Starbucks != 0]

# %%
# Second filter is "Nightlife", because everyone in the company is between 25 and 40, and need some place to go party.
#setting the radius to 500 and limiting search to 50.

# %%
def getNearbyNightlife(lat, long, radius=500):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&categories=13003&exclude_all_chains=false&sort=DISTANCE&limit=50"

    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }
    
    results = requests.get(url,headers=headers).json()["results"]
    
    return len(results)

# %%
for index, row in df.iterrows():
    df.at[index, "Nightlife"] = getNearbyNightlife(row["latitude"],row["longitude"])

# %%
#for index, row in df.iterrows():
 #   if getNearbyNightlife(row["latitude"],row["longitude"]) == True:
  #      df.at[index, "Nightlife"] = True
   # else :
    #    df.at[index, "Nightlife"] = False

# %%
df['Nightlife'] = df['Nightlife'].astype(int)

# %%
#df

# %%
nl_count = df["Nightlife"].value_counts()
print(nl_count.to_string())
# Out:
# 50    70
# 49     5
# 40     3
# 42     3
# 12     2
# 46     2
# 44     2
# 47     1
# 6      1
# 9      1
# 48     1
# 26     1
# 13     1
# 39     1
# 11     1
# 27     1
# 20     1
# 31     1
# 17     1

# %%
df = df[df.Nightlife != 0]

# %%
city_count = df["country_code"].value_counts()
print(city_count.to_string())
# Out:
# USA    93
# GBR     3
# SGP     2
# ESP     1

# %%
# Third filter is Transportation, specifically train station,metro station and taxi.
#assuming that airports are generally located outside cities, by choosing an office near an airport,
#we are going to be discarding other criterias that can't be found near airports, such as schools,pet grooming services...
#setting the radius to 500 and limiting search to 50.

#19047 rail
#19049 taxi
#19046 metro

# %%
def getNearbyTransport(lat, long, radius=500):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&categories=19047%2C19049%2C19046&exclude_all_chains=false&sort=DISTANCE&limit=50"

    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }
    
    results = requests.get(url,headers=headers).json()["results"]
    
    return len(results)

# %%
for index, row in df.iterrows():
    df.at[index, "transportation"] = getNearbyTransport(row["latitude"],row["longitude"])

# %%
df['transportation'] = df['transportation'].astype(int)

# %%
df = df[df.transportation != 0]

# %%
transp_count = df["transportation"].value_counts()
#print(transp_count.to_string())
#df

# %%
#4th filter preschool
#30% of the company staff have at least 1 child.
#setting the radius to 1000 in this case

# %%
def getNearbypreschool(lat, long, radius=1000):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&categories=12056&exclude_all_chains=false&sort=DISTANCE&limit=50"

    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }
    
    results = requests.get(url,headers=headers).json()["results"]
    
    return len(results)

# %%
for index, row in df.iterrows():
    df.at[index, "preschool"] = getNearbypreschool(row["latitude"],row["longitude"])

# %%
df['preschool'] = df['preschool'].astype(int)

# %%
ps_count = df["preschool"].value_counts()
print(ps_count.to_string())
# Out:
# 4     16
# 5     15
# 10    13
# 6     12
# 0     12
# 2     11
# 3      8
# 1      7
# 14     7
# 16     7
# 12     6
# 7      6
# 9      5
# 13     3
# 15     3
# 11     2
# 8      1
# 20     1
# 17     1

# %%
df = df[df.preschool != 0]

# %%
city_count = df["country_code"].value_counts()
print(city_count.to_string())
# Out:
# USA    113
# GBR      5
# SGP      2
# ESP      2
# FRA      1
# CAN      1

# %%
#5th filter is vegan restaurants

# %%
def getNearbyVeganRest(lat, long, radius=500):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&categories=13377&exclude_all_chains=false&sort=DISTANCE&limit=50"

    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }
    
    results = requests.get(url,headers=headers).json()["results"]
    
    return len(results)

# %%
for index, row in df.iterrows():
    df.at[index, "veganRest"] = getNearbyVeganRest(row["latitude"],row["longitude"])

# %%
df['veganRest'] = df['veganRest'].astype(int)

# %%
vegan_count = df["veganRest"].value_counts()
#print(vegan_count.to_string())
#df

# %%
city_count = df["country_code"].value_counts()
print(city_count.to_string())
# Out:
# USA    113
# GBR      5
# SGP      2
# ESP      2
# FRA      1
# CAN      1

# %%
df = df[df.veganRest != 0]

# %%
#The office dog—"Dobby" needs a hairdresser every month. Ensure there's one not too far away.
#the radius is set to 1000, Dobby only needs to go there once a month

# %%
def getNearbyPetService(lat, long, radius=1000):

    # create the API request URL
    url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&radius={radius}&categories=11134&exclude_all_chains=false&sort=DISTANCE"

    # make the GET request
    headers = {
    "accept": "application/json",
    "Authorization": token_fsq
    }
    
    results = requests.get(url,headers=headers).json()["results"]
    
    return len(results)

# %%
for index, row in df.iterrows():
    df.at[index, "petService"] = getNearbyPetService(row["latitude"],row["longitude"])

# %%
#df

# %%
df['petService'] = df['petService'].astype(int)

# %%
Ps_count = df["petService"].value_counts()
print(Ps_count.to_string())
# Out:
# 3     15
# 1     14
# 2     14
# 0     11
# 4     11
# 28     5
# 7      5
# 8      5
# 15     4
# 5      4
# 19     3
# 27     2
# 9      2
# 29     2
# 11     2
# 12     2
# 6      2
# 13     1
# 25     1
# 26     1
# 21     1
# 24     1
# 23     1
# 14     1

# %%
df = df[df.petService != 0]

# %%
city_count = df["country_code"].value_counts()
print(city_count.to_string())
# Out:
# USA    93
# GBR     3
# SGP     2
# ESP     1

# %%
city_count = df["city"].value_counts()
print(city_count.to_string())
# Out:
# New York         45
# San Francisco    35
# Seattle           6
# London            3
# Boston            2
# Singapore         2
# Bellevue          1
# Los Angeles       1
# Culver City       1
# Denver            1
# San Diego         1
# Madrid            1

# %%
test1 = df[~df.country_code.str.contains("USA")]
test1
# Out:
#             name       city   latitude   longitude country_code  Starbucks  \
# 55         Wonga     London  51.519204   -0.162610          GBR          3
# 64         mig33  Singapore  37.580304 -122.343679          SGP          1
# 149      Globant     London  51.520510   -0.095220          GBR          2
# 287       Nexway     Madrid  40.414299   -3.703307          ESP          4
# 288       Nexway  Singapore   1.307505  103.829500          SGP          6
# 314  Netbiscuits     London  51.513248   -0.154738          GBR          3
#
#      Nightlife  transportation  preschool  veganRest  petService
# 55          11              14          1          2           1
# 64           1               5          7          1           2
# 149          5               6          5          2           1
# 287         24               5          4         12           2
# 288         24               1          4          3           1
# 314          9               6          1          3           1

# %%
df.to_csv("./dataset/world_dataset.csv", index = False)

# %%
new_df = pd.read_csv("./dataset/world_dataset.csv")

# %%
new_df
# Out:
#               name           city   latitude   longitude country_code  \
# 0         Wetpaint        Seattle  47.603122 -122.333253          USA
# 1         Wetpaint       New York  40.723731  -73.996431          USA
# 2      StumbleUpon  San Francisco  37.775196 -122.419204          USA
# 3           Meetup       New York  40.726040  -73.995722          USA
# 4             Bebo  San Francisco  37.782103 -122.401116          USA
# ..             ...            ...        ...         ...          ...
# 94          Firm58       New York  40.766734  -73.988265          USA
# 95     ACT Biotech  San Francisco  37.787131 -122.404107          USA
# 96  Optimum Energy       New York  40.751892  -73.987592          USA
# 97         EnerNOC         Boston  42.355246  -71.056915          USA
# 98          OpTier       New York  40.754937  -73.985647          USA
#
#     Starbucks  Nightlife  transportation  preschool  veganRest  petService
# 0           2         11              11          4          1           3
# 1           3         17               9          9         10           7
# 2           2          2               6         10          4           3
# 3           4         12               8         12          8          13
# 4           2         10               1          5          1           3
# ..        ...        ...             ...        ...        ...         ...
# 94          5         10               1          9          2           8
# 95         11          6              12          5          3           2
# 96         14         28              19         13          7          12
# 97          7          2              16         11          6           1
# 98          9         29               9         10         10           5
#
# [99 rows x 11 columns]

# %%
new_df["Total"] = (new_df["Starbucks"])+(new_df["Nightlife"])+(new_df["transportation"])+(new_df["preschool"])+(new_df["veganRest"])+(new_df["petService"])

# %%
new_df["Ratio"] = (new_df["Starbucks"]*1)+(new_df["Nightlife"]*0.8)+(new_df["transportation"]*0.9)+(new_df["preschool"]*0.7)+(new_df["veganRest"]*0.6)+(new_df["petService"]*0.6)

# %%
new_df = new_df.sort_values(by='Ratio', ascending=False)
new_df
# Out:
#               name           city   latitude   longitude country_code  \
# 96  Optimum Energy       New York  40.751892  -73.987592          USA
# 90    Crispy Gamer       New York  40.750597  -73.985273          USA
# 14           Heavy       New York  40.753385  -73.989620          USA
# 77           Yipit       New York  40.744618  -73.987764          USA
# 40       Tripology       New York  40.746883  -73.983969          USA
# ..             ...            ...        ...         ...          ...
# 26    Doppelganger  San Francisco  37.762162 -122.413912          USA
# 58      InsideView  San Francisco  37.764169 -122.402021          USA
# 21           mig33      Singapore  37.580304 -122.343679          SGP
# 20      Smartsheet       Bellevue  47.617842 -122.200520          USA
# 59       WideOrbit  San Francisco  37.789529 -122.388590          USA
#
#     Starbucks  Nightlife  transportation  preschool  veganRest  petService  \
# 96         14         28              19         13          7          12
# 90         11         29              13         13          9          19
# 14         14         22              26         12          5           8
# 77          9         16              12         14         14          28
# 40          8         15              13         16         12          26
# ..        ...        ...             ...        ...        ...         ...
# 26          1          4               1         10          1           4
# 58          2          4               2          9          1           2
# 21          1          1               5          7          1           2
# 20          5          1               1          4          2           2
# 59          3          1               2          3          1           4
#
#     Total  Ratio
# 96     93   74.0
# 90     94   71.8
# 14     87   71.2
# 77     93   67.6
# 40     90   65.7
# ..    ...    ...
# 26     21   15.1
# 58     20   15.1
# 21     17   13.0
# 20     15   11.9
# 59     14   10.7
#
# [99 rows x 13 columns]

# %%
companies_group = folium.FeatureGroup(name=f"Companies: {new_df.shape[0]}")

# %%
wolrd_map  = Map(location = ["41.382707", "2.169242"], zoom_start = 2)
HeatMap(data=new_df[["latitude", "longitude"]], 
        radius=25,
       gradient = {0.4: 'yellow', 0.65: 'orange', 1: 'white'}).add_to(companies_group)

# %%
companies_group.add_to(wolrd_map)

# %%
wolrd_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a13a5db6941c7f590bc20a97afc3da09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a13a5db6941c7f590bc20a97afc3da09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a13a5db6941c7f590bc20a97afc3da09 = L.map(
#                 &quot;map_a13a5db6941c7f590bc20a97afc3da09&quot;,
#                 {
#                     center: [41.382707, 2.169242],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43ba36f349b8ca0efd4a9efea5af76f2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a13a5db6941c7f590bc20a97afc3da09);
#
#
#             var feature_group_2f046b31ec618ce3a73a05af59a4bddd = L.featureGroup(
#                 {}
#             ).addTo(map_a13a5db6941c7f590bc20a97afc3da09);
#
#
#             var heat_map_2580f00a462bd406df0274dda39311c3 = L.heatLayer(
#                 [[40.7518919, -73.9875922], [40.750597, -73.985273], [40.753385, -73.98962], [40.744618, -73.987764], [40.746883, -73.983969], [40.744837, -73.983843], [40.744639, -73.983963], [40.745216, -73.982807], [40.743808, -73.983626], [40.743808, -73.983626], [40.73906, -73.990911], [40.741179, -73.993182], [40.7387945, -73.9939213], [40.754937, -73.985647], [40.752957, -73.98546], [40.754211, -73.97917], [40.757929, -73.985506], [40.757929, -73.985506], [40.752672, -73.97593], [40.756054, -73.986951], [40.739341, -73.988357], [40.736796, -73.988339], [40.739794, -73.985878], [40.720824, -74.00007], [40.732748, -73.992607], [40.7619759, -73.9725773], [32.7154, -117.1565], [40.724604, -73.996876], [40.74727, -73.9800645], [40.761855, -73.983754], [40.762674, -73.9821315], [40.717248, -74.002662], [40.707729, -74.007801], [40.707729, -74.007801], [40.72604, -73.995722], [40.7311317, -73.9919311], [40.7237306, -73.9964312], [40.735327, -73.988469], [40.755253, -73.992152], [40.4142986, -3.7033074], [42.35892, -71.05781], [37.7955307, -122.4005983], [42.355246, -71.056915], [37.79471, -122.40195], [40.705439, -74.012822], [40.74034, -74.00721], [37.7871306, -122.4041075], [47.601803, -122.332085], [37.790964, -122.401128], [1.307505, 103.8295], [37.7911148, -122.3954751], [37.794643, -122.401144], [37.790346, -122.40185], [37.788266, -122.403865], [37.7905538, -122.4041485], [37.7893215, -122.4013624], [40.725883, -74.006196], [47.6136485,
# 23          2          2               6         10          4           3
# 7           6          7               5          3          2           1
# 25          4          4               7          4          2           4
# 51          4          9               5          3          1           2
# 19          2         10               6          3          1           2
# 52          2          9               1          2          3           9
# 29          8          2               3          3          3           3
# 30          3          5               2          9          1           3
# 57          1          2               1          7          8           7
# 6           4          4               3          6          1           4
# 4           2         10               1          5          1           3
# 83          4          4               2          4          2           4
# 26          1          4               1         10          1           4
# 58          2          4               2          9          1           2
# 20          5          1               1          4          2           2
# 59          3          1               2          3          1           4
#
#     Total  Ratio
# 96     93   74.0
# 90     94   71.8
# 14     87   71.2
# 77     93   67.6
# 40     90   65.7
# 32     89   63.5
# 34     88   62.5
# 22     86   61.6
# 41     85   59.8
# 24     85   59.8
# 45     83   59.1
# 72     81   58.4
# 46     81   57.4
# 98     72   56.3
# 12     71   55.5
# 60     71   55.2
# 16     65   52.3
# 35     65   52.3
# 89     66   50.6
# 64     63   50.2
# 56     70   48.9
# 62     69   48.7
# 37     70   48.6
# 36     64   47.8
# 42     66   46.1
# 78     63   46.1
# 82     59   45.3
# 55     60   44.4
# 27     59   43.7
# 47     54   43.3
# 88     53   42.6
# 38     56   42.2
# 73     53   41.9
# 75     53   41.9
# 3      57   41.8
# 8      59   41.5
# 1      55   41.2
# 44     59   41.2
# 70     50   40.4
# 11     46   37.1
# 39     43   35.3
# 97     43   34.9
# 43     43   34.7
# 79     42   33.8
# 66     46   33.8
# 95     39   33.1
# 61     39   31.9
# 13     37   31.4
# 9      37   30.8
# 81     38   30.7
# 28     36   30.3
# 31     36   30.1
# 84     35   29.6
# 69     35   29.4
# 33     41   29.2
# 80     36   28.2
# 68     34   26.6
# 94     35   26.2
# 15     31   26.1
# 92     38   26.1
# 54     38   26.1
# 10     32   26.0
# 0      32   25.9
# 91     30   24.4
# 76     30   24.4
# 74     30   24.4
# 18     32   23.9
# 50     28   22.3
# 85     26   20.6
# 53     26   20.6
# 71     27   20.2
# 48     27   20.2
# 63     27   20.2
# 2      27   20.2
# 5      27   20.2
# 65     27   20.2
# 67     27   20.2
# 23     27   20.2
# 7      24   20.0
# 25     25   19.9
# 51     24   19.6
# 19     24   19.3
# 52     26   18.7
# 29     22   18.0
# 30     23   17.5
# 57     26   17.4
# 6      22   17.1
# 4      22   16.8
# 83     20   15.4
# 26     21   15.1
# 58     20   15.1
# 20     15   11.9
# 59     14   10.7

# %%
ny_df = usa_df[usa_df["city"] == "New York"]
ny_df
#select all NY
#ratio helps me decide on the top 10 companies
# Out:
#                    name      city   latitude  longitude country_code  \
# 96       Optimum Energy  New York  40.751892 -73.987592          USA
# 90         Crispy Gamer  New York  40.750597 -73.985273          USA
# 14                Heavy  New York  40.753385 -73.989620          USA
# 77                Yipit  New York  40.744618 -73.987764          USA
# 40            Tripology  New York  40.746883 -73.983969          USA
# 32               stickK  New York  40.744837 -73.983843          USA
# 34  Inform Technologies  New York  40.744639 -73.983963          USA
# 22                Mimeo  New York  40.745216 -73.982807          USA
# 41    Next New Networks  New York  40.743808 -73.983626          USA
# 24               Tumblr  New York  40.743808 -73.983626          USA
# 70          8         14              13          5          3           7
# 79          8          4              13          7          5           5
# 66          3         19               2          6          4          12
# 33          2          4               8          6          6          15
# 94          5         10               1          9          2           8
# 92          2          3               4          7          7          15
# 54          2          3               4          7          7          15
# 18          6          1               3         12          5           5
#
#     Total  Ratio
# 96     93   74.0
# 90     94   71.8
# 14     87   71.2
# 77     93   67.6
# 40     90   65.7
# 32     89   63.5
# 34     88   62.5
# 22     86   61.6
# 41     85   59.8
# 24     85   59.8
# 45     83   59.1
# 72     81   58.4
# 46     81   57.4
# 98     72   56.3
# 12     71   55.5
# 60     71   55.2
# 16     65   52.3
# 35     65   52.3
# 89     66   50.6
# 64     63   50.2
# 56     70   48.9
# 62     69   48.7
# 37     70   48.6
# 36     64   47.8
# 42     66   46.1
# 78     63   46.1
# 55     60   44.4
# 27     59   43.7
# 47     54   43.3
# 88     53   42.6
# 38     56   42.2
# 73     53   41.9
# 75     53   41.9
# 3      57   41.8
# 8      59   41.5
# 1      55   41.2
# 44     59   41.2
# 70     50   40.4
# 79     42   33.8
# 66     46   33.8
# 33     41   29.2
# 94     35   26.2
# 92     38   26.1
# 54     38   26.1
# 18     32   23.9

# %%
ny_df.to_csv("./dataset/new_york_data.csv", index = False)

# %%
nyork_df = pd.read_csv("./dataset/new_york_data.csv")

# %%
NY_map = Map(location = ["40.751892", "-73.987592"], zoom_start = 10)
folium.Circle([40.751892, -73.987592],radius=1000).add_to(NY_map)

# %%
NY_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8286e0c9eb72485a35b48573cd041d23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8286e0c9eb72485a35b48573cd041d23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8286e0c9eb72485a35b48573cd041d23 = L.map(
#                 &quot;map_8286e0c9eb72485a35b48573cd041d23&quot;,
#                 {
#                     center: [40.751892, -73.987592],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_524ad46487b4162487a2fd35ba8272d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8286e0c9eb72485a35b48573cd041d23);
#
#
#             var circle_aa83ebbd37594d956df526d08b37f279 = L.circle(
#                 [40.751892, -73.987592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8286e0c9eb72485a35b48573cd041d23);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#top 10 locations in NY based on ratio

# %%
top_ny= nyork_df.head(10)
top_ny
# Out:
#                   name      city   latitude  longitude country_code  \
# 0       Optimum Energy  New York  40.751892 -73.987592          USA
# 1         Crispy Gamer  New York  40.750597 -73.985273          USA
# 2                Heavy  New York  40.753385 -73.989620          USA
# 3                Yipit  New York  40.744618 -73.987764          USA
# 4            Tripology  New York  40.746883 -73.983969          USA
# 5               stickK  New York  40.744837 -73.983843          USA
# 6  Inform Technologies  New York  40.744639 -73.983963          USA
# 7                Mimeo  New York  40.745216 -73.982807          USA
# 8    Next New Networks  New York  40.743808 -73.983626          USA
# 9               Tumblr  New York  40.743808 -73.983626          USA
#
#    Starbucks  Nightlife  transportation  preschool  veganRest  petService  \
# 0         14         28              19         13          7          12
# 1         11         29              13         13          9          19
# 2         14         22              26         12          5           8
# 3          9         16              12         14         14          28
# 4          8         15              13         16         12          26
# 5         10         11               8         15         17          28
# 6          9         11               8         15         17          28
# 7          8         12              10         14         15          27
# 8          8         11               6         16         16          28
# 9          8         11               6         16         16          28
#
#    Total  Ratio
# 0     93   74.0
# 1     94   71.8
# 2     87   71.2
# 3     93   67.6
# 4     90   65.7
# 5     89   63.5
# 6     88   62.5
# 7     86   61.6
# 8     85   59.8
# 9     85   59.8

# %%
TOP_NY_map = Map(location = ["40.751892", "-73.987592"], zoom_start = 15)

# %%
icon = Icon(color = "blue",
            opacity = 0.1,
            prefix = "fa",
            icon = "briefcase",
            icon_color = "black")

# %%
for index, row in top_ny.iterrows():
    
    folium.Circle([row["latitude"],row["longitude"]],radius=1000).add_to(TOP_NY_map)
    folium.Marker(location =[row["latitude"],row["longitude"]],tooltip = row["name"],icon = icon).add_to(TOP_NY_map)

# %%
TOP_NY_map2 = Map(location = ["40.751892", "-73.987592"], zoom_start = 15)

# %%
for index, row in top_ny.iterrows():
    
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    
    new_marker = Marker(**district, icon = icon, radius = 1000)
    
    #4. Add the Marker
    new_marker.add_to(TOP_NY_map2)

# %%
TOP_NY_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31dc32a93d05bfb8c34275dfd1fa9bfb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31dc32a93d05bfb8c34275dfd1fa9bfb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_31dc32a93d05bfb8c34275dfd1fa9bfb = L.map(
#                 &quot;map_31dc32a93d05bfb8c34275dfd1fa9bfb&quot;,
#                 {
#                     center: [40.751892, -73.987592],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3786c752df38585143ff2d410aff2ebc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             var marker_520d3eac14071335ec3ab85e37d7a265 = L.marker(
#                 [40.7518919, -73.9875922],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             var icon_e8e51436e4c47ea64ade058485b4fe25 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5fc82fde74f9df3fac0afe777ff65ba7.setIcon(icon_e8e51436e4c47ea64ade058485b4fe25);
#
#
#             marker_520d3eac14071335ec3ab85e37d7a265.bindTooltip(
#                 `&lt;div&gt;
#                      Optimum Energy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c6a06df4deb7f6a389e9e6dcd929c846 = L.marker(
#                 [40.750597, -73.985273],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             marker_c6a06df4deb7f6a389e9e6dcd929c846.bindTooltip(
#                 `&lt;div&gt;
#                      Crispy Gamer
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4f183a3fb7b48c3b7142f18928ee5c2d = L.marker(
#                 [40.753385, -73.98962],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             marker_4f183a3fb7b48c3b7142f18928ee5c2d.bindTooltip(
#                 `&lt;div&gt;
#                      Heavy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d1d806ba2dc018380201be1ebe88444 = L.marker(
#                 [40.744618, -73.987764],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             marker_9d1d806ba2dc018380201be1ebe88444.bindTooltip(
#                 `&lt;div&gt;
#                      Yipit
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e62b96447c7cd378b8b2818e6ae0698a = L.marker(
#                 [40.746883, -73.983969],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             marker_e62b96447c7cd378b8b2818e6ae0698a.bindTooltip(
#                 `&lt;div&gt;
#                      Tripology
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_61b0afbaddedc49dfdb78150d70a410a = L.marker(
#                 [40.744837, -73.983843],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             marker_61b0afbaddedc49dfdb78150d70a410a.bindTooltip(
#                 `&lt;div&gt;
#                      stickK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7c719c088870701865a9af154fd90470 = L.marker(
#                 [40.744639, -73.983963],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             marker_7c719c088870701865a9af154fd90470.bindTooltip(
#                 `&lt;div&gt;
#                      Inform Technologies
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_241e3e87368c2204490c41221ae6b766 = L.marker(
#                 [40.745216, -73.982807],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_31dc32a93d05bfb8c34275dfd1fa9bfb);
#
#
#             marker_241e3e87368c2204490c41221ae6b766.bindTooltip(
#                 `&lt;div&gt;
#                      Mimeo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e6ea6151f7f6f6801e171fd83b66f04e = L.marker(
#                 [40.743808, -73.983626],
#                 {&quot;radius&quot;:

# %%
TOP_NY_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_767eef912330f51e3723d79bbb96e519 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_767eef912330f51e3723d79bbb96e519&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_767eef912330f51e3723d79bbb96e519 = L.map(
#                 &quot;map_767eef912330f51e3723d79bbb96e519&quot;,
#                 {
#                     center: [40.751892, -73.987592],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5acda27c1b3c542109635626afe54308 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_767eef912330f51e3723d79bbb96e519);
#
#
#             var circle_98257ff0b8224f215ac08e510f575e43 = L.circle(
#                 [40.7518919, -73.9875922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_767eef912330f51e3723d79bbb96e519);
#
#
#             var marker_5f0d9faf5754b72aac981b62322f6365 = L.marker(
#                 [40.7518919, -73.9875922],
#                 {}
#             ).addTo(map_767eef912330f51e3723d79bbb96e519);
#
#
#             var icon_e8e51436e4c47ea64ade058485b4fe25 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c0e78325ea9506d5af14adf19d42e503.setIcon(icon_e8e51436e4c47ea64ade058485b4fe25);
#
#
#             marker_5f0d9faf5754b72aac981b62322f6365.bindTooltip(
#                 `&lt;div&gt;
#                      Optimum Energy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_64e1310e746bb64d9b0b9a41c2e0e376 = L.circle(
#                 [40.750597, -73.985273],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_767eef912330f51e3723d79bbb96e519);
#
#
#             var marker_b76ea4d859c1007bcdfc2678f1203b58 = L.marker(
#                 [40.750597, -73.985273],
#                 {}
#             ).addTo(map_767eef912330f51e3723d79bbb96e519);
#
#
#             marker_b76ea4d859c1007bcdfc2678f1203b58.bindTooltip(
#                 `&lt;div&gt;
#                      Crispy Gamer
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_de2d367ce789931530edaa7758ba434c = L.circle(
#                 [40.753385, -73.98962],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_767eef912330f51e3723d79bbb96e519);
#
#
#             var marker_0ef6e8aeb186c37534ad96716d7dda7d = L.marker(
#                 [40.753385, -73.98962],
#                 {}
#             ).addTo(map_767eef912330f51e3723d79bbb96e519);
#
#
#             marker_0ef6e8aeb186c37534ad96716d7dda7d.bindTooltip(
#                 `&lt;div&gt;
#                      Heavy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_cf369ee4d2ad48fff366ae66b3c4a6cc = L.circle(
#                 [40.744618, -73.987764],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;roun

# %%
#get surroundings using api call for each amenity
#json into data frame
#plotting final data frame of my chosen location with amenities around
#using same code for mapping companies  or the code from lecture

# %%
top_NY_df = NY_df.head(3)

# %% [markdown]
# import geopy.distance
# ​
# coords_1 = (52.2296756, 21.0122287)
# coords_2 = (52.406374, 16.9251681)
# ​
# print (geopy.distance.geodesic(coords_1, coords_2).km)
